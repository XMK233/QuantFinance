# %%
with open("/mnt/d/forCoding_code/_init_tools/x__params.py", "r") as f:
    txt = f.read()
exec(txt)

with open("/mnt/d/forCoding_code/_init_tools/report_macro_0516.py", "r") as f:
    txt = f.read()
exec(txt)

with open("/mnt/d/forCoding_code/_init_tools/x__tool_here1.py", "r") as f:
    exec(f.read())
with open("/mnt/d/forCoding_code/_init_tools/x__tool_here2.py", "r") as f:
    exec(f.read())

wasted_dir = "./wasted"
if not os.path.exists(wasted_dir):
    os.makedirs(wasted_dir)

pd.set_option('display.max_rows',200)
pd.set_option('display.max_columns',200)
# Out:
# storage dir: /mnt/d/forCoding_data/QuantFinance/plan_3-standardization_1
# code dir: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1

# %%
# !python daily_trading_system.py --strategy bottom_doji --ignore-holdings # --skip-update --recommend-only
# Out:
# 🚀 启动每日交易系统 - 2026-06-18 22:16
# ================================================================================
# 📊 开始更新每日数据...
# 🔐 登录baostock...
# login success!
# baostock登录成功
# 📅 更新日线数据...
# 🚀 开始高效并行增量更新日线数据...
# 🔧 需要更新 1 只股票的数据
# 📝 需要更新的股票示例 (前1只):
#    1. sz.002496 - 2026-04-17 到 2026-06-18
# 日线并行下载:   0%|                                       | 0/1 [00:00<?, ?股/s]login success!
# 日线并行下载: 100%|██████| 1/1 [00:02<00:00,  2.02s/股, 成功=1, 失败=0, 数据=42]
# ✅ 日线更新完成: 成功 1, 失败 0, 新增数据 42 条
# ✅ 日线数据更新成功: 42 条记录
# 📌 周线目标日期: 2026-06-12 | 待补全股票数: 2174
# 📈 更新周线数据...
# 🚀 开始高效并行增量更新周线数据...
# 🔧 需要更新 1 只股票的数据
# 📝 需要更新的股票示例 (前1只):
#    1. sz.002496 - 2026-04-11 到 2026-06-12
# 周线并行下载:   0%|                                       | 0/1 [00:00<?, ?股/s]login success!
# 周线并行下载: 100%|███████| 1/1 [00:01<00:00,  1.94s/股, 成功=1, 失败=0, 数据=9]
# ✅ 周线更新完成: 成功 1, 失败 0, 新增数据 9 条
# ✅ 周线数据更新成功: 9 条记录
# ✅ 数据更新完成
# logout success!
# baostock已登出
#
# 📦 当前持仓监控:
# ================================================================================
#  3. sh.600888  | 名称: 新疆众和   | 现价:  12.30 | 成本:  11.05 | 收益: 11.3% | 回撤: 0.0%
#  1. sz.000725  | 名称: 京东方A   | 现价:   6.71 | 成本:   5.27 | 收益: 27.3% | 回撤: 0.0%
#  2. sz.003019  | 名称: 宸展光电   | 现价:  35.02 | 成本:  41.40 | 收益: -15.4% | 回撤: 15.4%
#
# 📉 卖出建议:
# ================================================================================
#  2. sz.003019  | 名称: 宸展光电   | 现价:  35.02 | 成本:  41.40 | 收益: -15.4% | 原因: 止损(8%) | 跌破20日均线 | 周线MA20转弱 | 预估手续费: 5.00
#  1. sz.000725  | 名称: 京东方A   | 现价:   6.71 | 成本:   5.27 | 收益: 27.3% | 原因: 固定止盈(20%) | 预估手续费: 5.00
# 底部十字星策略选股: 100%|████████████████| 3196/3196 [00:35<00:00, 90.76stock/s]
#
# 💾 策略结果已保存到: /mnt/d/forCoding_data/QuantFinance/plan_3-standardization_1/recommendations/strategy_chain_bottom_doji_20260618.csv
#
# 🖼️  绘制入股候选的日K/周K（共 3 只）...
# 🖼️  已生成日K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260618/sz.002393_daily.png
# 🖼️  已生成周K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260618/sz.002393_weekly.png
# 🖼️  已生成日K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260618/sz.001311_daily.png
# 🖼️  已生成周K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260618/sz.001311_weekly.png
# 🖼️  已生成日K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260618/sh.605499_daily.png
# 🖼️  已生成周K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260618/sh.605499_weekly.png
#
# 📋 具体交易计划:
# ================================================================================
# 💰 总资金: 50,000 元
# 📊 最大持仓数: 3 只
# 📊 单只股票目标资金: 16,667 元
#
# 🎯 建议操作:
#  1. sz.002393  力生制药   - 建议买入: 1,100 股 | 价格:  14.18元 | 投入: 15,598元 | 手续费: 5.00元 | 置信度: 70.0%
#  2. sz.001311  多利科技   - 建议买入: 900 股 | 价格:  18.11元 | 投入: 16,299元 | 手续费: 5.00元 | 置信度: 70.0%
#  3. sh.605499  东鹏饮料   - 建议买入: 100 股 | 价格: 125.39元 | 投入: 12,539元 | 手续费: 5.00元 | 置信度: 70.0%
#
# ================================================================================
# ✅ 每日交易系统执行完成
# ⏰ 完成时间: 2026-06-18 22:17

# %%
# !python daily_trading_system.py --recommend-only --strategy weekly_mean_down cross_ma50 --ignore-holdings # --skip-update
# Out:
# 🚀 启动每日交易系统 - 2026-06-18 22:17
# ================================================================================
#
# 📦 当前持仓监控:
# ================================================================================
#  3. sh.600888  | 名称: 新疆众和   | 现价:  12.30 | 成本:  11.05 | 收益: 11.3% | 回撤: 0.0%
#  1. sz.000725  | 名称: 京东方A   | 现价:   6.71 | 成本:   5.27 | 收益: 27.3% | 回撤: 0.0%
#  2. sz.003019  | 名称: 宸展光电   | 现价:  35.02 | 成本:  41.40 | 收益: -15.4% | 回撤: 15.4%
#
# 📉 卖出建议:
# ================================================================================
#  2. sz.003019  | 名称: 宸展光电   | 现价:  35.02 | 成本:  41.40 | 收益: -15.4% | 原因: 止损(8%) | 跌破20日均线 | 周线MA20转弱 | 预估手续费: 5.00
#  1. sz.000725  | 名称: 京东方A   | 现价:   6.71 | 成本:   5.27 | 收益: 27.3% | 原因: 固定止盈(20%) | 预估手续费: 5.00
# 周均价下移策略选股: 100%|████████████████| 3196/3196 [00:34<00:00, 91.45stock/s]
# 一阳穿四线策略选股: 100%|█████████████████| 500/500 [00:04<00:00, 114.82stock/s]
#
# 💾 策略结果已保存到: /mnt/d/forCoding_data/QuantFinance/plan_3-standardization_1/recommendations/strategy_chain_weekly_mean_down_cross_ma50_20260618.csv
#
# 🖼️  绘制入股候选的日K/周K（共 3 只）...
# 🖼️  已生成日K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260618/sz.001696_daily.png
# 🖼️  已生成周K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260618/sz.001696_weekly.png
# 🖼️  已生成日K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260618/sh.603669_daily.png
# 🖼️  已生成周K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260618/sh.603669_weekly.png
# 🖼️  已生成日K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260618/sh.603194_daily.png
# 🖼️  已生成周K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260618/sh.603194_weekly.png
#
# 📋 具体交易计划:
# ================================================================================
# 💰 总资金: 50,000 元
# 📊 最大持仓数: 3 只
# 📊 单只股票目标资金: 16,667 元
#
# 🎯 建议操作:
#  1. sz.001696  宗申动力   - 建议买入: 600 股 | 价格:  24.22元 | 投入: 14,532元 | 手续费: 5.00元 | 置信度: 70.0%
#  2. sh.603669  灵康药业   - 建议买入: 3,400 股 | 价格:   4.82元 | 投入: 16,388元 | 手续费: 5.00元 | 置信度: 70.0%
#  3. sh.603194  中力股份   - 建议买入: 400 股 | 价格:  37.04元 | 投入: 14,816元 | 手续费: 5.00元 | 置信度: 70.0%
#
# ================================================================================
# ✅ 每日交易系统执行完成
# ⏰ 完成时间: 2026-06-18 22:18

# %%
# !python daily_trading_system.py --clear-positions --recommend-only --strategy multi_factor --ignore-holdings --price-cap 50
# Out:
# 🚀 启动每日交易系统 - 2026-06-18 22:27
# ================================================================================
# 🧹 已清空持仓记录: /mnt/d/forCoding_data/QuantFinance/plan_3-standardization_1/positions.csv
#
# 🎯 生成交易推荐...
# --------------------------------------------------
# 📊 生成每日交易推荐...
# 🚫 已启用创业板股票过滤
# 🚫 已启用科创板股票过滤
# 📈 今日推荐买入股票:
# ================================================================================
#  4. sh.605198  | 名称: 安德利    | 价格:  86.10 | 置信度: 68.0% | 理由: 价格在20日均线之上 | 放量突破次数达标 | 突破后回调到位 | 周线突破20周新高(放量) | ...
#  6. sz.002129  | 名称: TCL中环  | 价格:  10.71 | 置信度: 68.0% | 理由: 价格在20日均线之上 | 近期有一阳穿四线 | 放量突破次数达标 | 回调MA20后反弹 | 周线M...
#  1. sh.603020  | 名称: 爱普股份   | 价格:  13.89 | 置信度: 63.0% | 理由: 价格在20日均线之上 | 近期有一阳穿四线 | 周线突破20周新高(放量) | 周线MA20连续上行...
#  5. sz.000823  | 名称: 超声电子   | 价格:  22.11 | 置信度: 63.0% | 理由: 价格在20日均线之上 | 突破后回调到位 | 周线突破20周新高(放量) | 回调MA20后反弹 |...
#  2. sh.603194  | 名称: 中力股份   | 价格:  37.04 | 置信度: 60.0% | 理由: 价格在20日均线之上 | 近期有一阳穿四线 | 放量突破次数达标 | 回调MA20后反弹...
#  3. sh.603995  | 名称: 甬金股份   | 价格:  21.38 | 置信度: 60.0% | 理由: 价格在20日均线之上 | 近期有一阳穿四线 | 放量突破次数达标 | 回调MA20后反弹...
#  7. sz.002935  | 名称: 天奥电子   | 价格:  22.15 | 置信度: 60.0% | 理由: 价格在20日均线之上 | 近期有一阳穿四线 | 放量突破次数达标 | 回调MA20后反弹...
#
# 💾 推荐结果已保存到: /mnt/d/forCoding_data/QuantFinance/plan_3-standardization_1/recommendations/trading_recommendations_20260618.csv
#
# 🖼️  绘制入股候选的日K/周K（共 3 只）...
# 🖼️  已生成日K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260618/sh.605198_daily.png
# 🖼️  已生成周K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260618/sh.605198_weekly.png
# 🖼️  已生成日K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260618/sz.002129_daily.png
# 🖼️  已生成周K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260618/sz.002129_weekly.png
# 🖼️  已生成日K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260618/sh.603020_daily.png
# 🖼️  已生成周K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260618/sh.603020_weekly.png
#
# 📋 具体交易计划:
# ================================================================================
# 💰 总资金: 50,000 元
# 📊 最大持仓数: 3 只
# 📊 单只股票目标资金: 16,667 元
#
# 🎯 建议操作:
#  4. sh.605198  安德利    - 建议买入: 100 股 | 价格:  86.10元 | 投入: 8,610元 | 手续费: 5.00元 | 置信度: 68.0%
#  6. sz.002129  TCL中环  - 建议买入: 1,500 股 | 价格:  10.71元 | 投入: 16,065元 | 手续费: 5.00元 | 置信度: 68.0%
#  1. sh.603020  爱普股份   - 建议买入: 1,100 股 | 价格:  13.89元 | 投入: 15,279元 | 手续费: 5.00元 | 置信度: 63.0%
#
# ================================================================================
# ✅ 每日交易系统执行完成
# ⏰ 完成时间: 2026-06-18 22:31

# %% [markdown]
# # recycle bin
