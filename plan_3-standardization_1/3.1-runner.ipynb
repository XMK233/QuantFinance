# %%
# !python daily_trading_system.py --recommend-only --workers 4 --strategy bottom_doji --ignore-holdings # --skip-update --recommend-only
# Out:
# 🚀 启动每日交易系统 - 2026-07-09 21:52
# ...
# 底部十字星策略选股: 100%|███████████████| 3202/3202 [00:31<00:00, 100.52stock/s]
#
# 💾 策略结果已保存到: /mnt/d/forCoding_data/QuantFinance/plan_3-standardization_1/recommendations/strategy_chain_bottom_doji_20260709.csv
#
# 🖼️  绘制入股候选的日K/周K（共 3 只）...
# 🖼️  已生成日K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260709/sh.600773_daily.png
# 🖼️  已生成周K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260709/sh.600773_weekly.png
# 🖼️  已生成日K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260709/sh.600158_daily.png
# 🖼️  已生成周K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260709/sh.600158_weekly.png
# 🖼️  已生成日K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260709/sz.002560_daily.png
# 🖼️  已生成周K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260709/sz.002560_weekly.png
#
# 📋 具体交易计划:
# ...
# 💰 总资金: 50,000 元
# ...

# %%
# !pip install -U baostock

# %%
# !python daily_trading_system.py --recommend-only --strategy weekly_mean_down cross_ma50 --ignore-holdings # # --skip-update
# Out:
# 🚀 启动每日交易系统 - 2026-07-09 21:53
# ...
# 一阳穿四线策略选股: 100%|█████████████████| 500/500 [00:01<00:00, 453.81stock/s]
#
# 💾 策略结果已保存到: /mnt/d/forCoding_data/QuantFinance/plan_3-standardization_1/recommendations/strategy_chain_weekly_mean_down_cross_ma50_20260709.csv
#
# 🖼️  绘制入股候选的日K/周K（共 3 只）...
# 🖼️  已生成日K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260709/sh.603983_daily.png
# 🖼️  已生成周K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260709/sh.603983_weekly.png
# 🖼️  已生成日K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260709/sh.600576_daily.png
# 🖼️  已生成周K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260709/sh.600576_weekly.png
# 🖼️  已生成日K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260709/sh.603072_daily.png
# 🖼️  已生成周K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260709/sh.603072_weekly.png
#
# 📋 具体交易计划:
# ...

# %%
# !python daily_trading_system.py --recommend-only --strategy cross_ma50 --ignore-holdings # # --skip-update
# Out:
# 🚀 启动每日交易系统 - 2026-07-09 21:53
# ...
# 一阳穿四线策略选股: 100%|███████████████| 3202/3202 [00:27<00:00, 115.85stock/s]
#
# 💾 策略结果已保存到: /mnt/d/forCoding_data/QuantFinance/plan_3-standardization_1/recommendations/strategy_chain_cross_ma50_20260709.csv
#
# 🖼️  绘制入股候选的日K/周K（共 3 只）...
# 🖼️  已生成日K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260709/sh.603137_daily.png
# 🖼️  已生成周K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260709/sh.603137_weekly.png
# 🖼️  已生成日K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260709/sh.603983_daily.png
# 🖼️  已生成周K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260709/sh.603983_weekly.png
# 🖼️  已生成日K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260709/sz.002841_daily.png
# 🖼️  已生成周K: /mnt/d/forCoding_code/QuantFinance/plan_3-standardization_1/kline_charts_20260709/sz.002841_weekly.png
#
# 📋 具体交易计划:
# ...
# 💰 总资金: 50,000 元
# ...

# %%
# !python daily_trading_system.py --clear-positions --recommend-only --strategy multi_factor --ignore-holdings --price-cap 50
# Out:
# 🚀 启动每日交易系统 - 2026-07-09 21:54
# ...
# 🧹 已清空持仓记录: /mnt/d/forCoding_data/QuantFinance/plan_3-standardization_1/positions.csv
#
# 🎯 生成交易推荐...
# --------------------------------------------------
# 📊 生成每日交易推荐...
# 🚫 已启用创业板股票过滤
# 🚫 已启用科创板股票过滤
# 📈 今日推荐买入股票:
# ...
#  6. sz.002850  | 名称: 科达利    | 价格: 196.97 | 置信度: 78.0% | 理由: 价格在20日均线之上 | 近期有一阳穿四线 | 放量突破次数达标 | 周线突破20周新高(放量) |...
#  3. sz.002472  | 名称: 双环传动   | 价格:  42.34 | 置信度: 70.0% | 理由: 价格在20日均线之上 | 近期有一阳穿四线 | 放量突破次数达标 | 周线突破20周新高(放量)...
#  4. sz.002687  | 名称: 乔治白    | 价格:   5.29 | 置信度: 70.0% | 理由: 价格在20日均线之上 | 近期有一阳穿四线 | 放量突破次数达标 | 周线突破20周新高(放量)...
#  1. sh.605007  | 名称: 五洲特纸   | 价格:  15.49 | 置信度: 60.0% | 理由: 价格在20日均线之上 | 近期有一阳穿四线 | 放量突破次数达标 | 回调MA20后反弹...
#  2. sz.000970  | 名称: 中科三环   | 价格:  15.93 | 置信度: 60.0% | 理由: 价格在20日均线之上 | 放量突破次数达标 | 突破后回调到位 | 周线突破20周新高(放量)...
#  5. sz.002841  | 名称: 视源股份   | 价格:  47.39 | 置信度: 60.0% | 理由: 价格在20日均线之上 | 近期有一阳穿四线 | 放量突破次数达标 | 回调MA20后反弹...
#
# ...

# %% [markdown]
# # recycle bin
