# %%
# !python run_backtest.py full \
  --start-date 2025-01-01 \
  --initial-capital 50000 \
  --max-positions 3 \
  --max-price 150.0 \
  --output-dir full_backtest_2025
# Out:
# ...
# 🚀 开始策略回测系统
# ...
# 📅 回测期间: 2025-01-01 至 2026-06-18
# 💰 初始资金: 50,000元
# 🎯 策略组合: weekly_mean_down + cross_ma50
# 📊 限制条件: 最多3只持仓, 单价≤150.0元
# ----------------------------------------------------------------------
# 1️⃣ 初始化数据管理器...
# 2️⃣ 获取交易日历...
# 📅 获取交易日历...
#   ✅ 获取到 351 个交易日
#   交易日数量: 351
# 3️⃣ 创建回测系统...
# 📅 获取交易日历...
# 4️⃣ 运行回测...
# 🚀 开始策略回测
# 📊 初始资金: 50000.00元
# 📈 策略组合: weekly_mean_down + cross_ma50
# 📅 回测期间: 2025-01-01 至 2026-06-18
# 🎯 限制条件: 最多3只持仓, 单价≤150.0元
# ------------------------------------------------------------
# ...
# 一阳穿四线策略选股: 100%|███████████████| 3196/3196 [00:25<00:00, 125.04stock/s]
#
# ...
# 周均价下移策略选股: 100%|████████████████████| 34/34 [00:00<00:00, 95.56stock/s]
#   📥 买入 sz.002568(百润股份): 2448股 @ 18.38, 成本: 44999.24元
#   📥 买入 sh.603669(灵康药业): 933股 @ 4.82, 成本: 4502.06元
# 回测 2025-03-03:  10%|██                   | 35/351 [00:26<00:51,  6.11交易日/s]  📤 卖出 sz.002568: 2448股 @ 18.38, 盈利: -5.00元 (持有时间到期: 60天)
#   📤 卖出 sh.603669: 933股 @ 4.82, 盈利: -5.00元 (持有时间到期: 60天)
#
# ...

# %% [raw]
# 能不能再帮我改进改进：我希望做一个类似于机器学习的手段，训练数据是历史上的k线周线日线行情，目标是未来的3周内是否能够盈利10%。我希望你能够基于weekly_mean_down cross_ma50两个基础策略，然后再考虑一些其他的东西（这些就要你来帮我设计了），设计一套交易体系，能够给我一些指导，让我能够买入新票或者卖出持仓，从而确保盈利目标。
